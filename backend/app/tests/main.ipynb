# %%
import pandas as pd

df = pd.read_parquet("../data/kafka_records_concat/2023-02-17T20:15.pqt")
df
# Out:
#                    created_at  exhauster_id  bearing_1.temperature.value  \
# 0  2023-02-02 07:42:25.599340             0                    62.699997
# 1  2023-02-02 07:42:25.599340             1                    53.699997
# 2  2023-02-02 07:42:25.599340             2                    21.900002
# 3  2023-02-02 07:42:25.599340             3                    12.800003
# 4  2023-02-02 07:42:25.599340             4                    43.599998
# ..                        ...           ...                          ...
# 1  2023-01-29 07:52:25.125007             1                    52.699997
# 2  2023-01-29 07:52:25.125007             2                    46.300003
# 3  2023-01-29 07:52:25.125007             3                    52.300003
# 4  2023-01-29 07:52:25.125007             4                    43.300003
# 5  2023-01-29 07:52:25.125007             5                    55.700005
#
#     bearing_1.temperature.alarm_max  bearing_1.temperature.alarm_min  \
# ...
